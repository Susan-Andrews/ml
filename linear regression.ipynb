# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# ### This is a linear regression model created for my education purpose . The equations are added after browsing  and are different from the previous notebook and plotted the model with help of python libraries.

# %% [markdown]
#  #### AGE-GLUCOSE MODEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Reading Data
data = pd.read_csv('age-glucose.csv')
# Printing the data  
print(data.head())
print("----------------")


# Collecting X and Y
X = data['age'].values
Y = data['glucose'].values


# Calculating coefficient

# Mean and Sum of  X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

sum_x=np.sum(X)
sum_y=np.sum(Y)

print("Mean age= "+ str(mean_x))
print("Mean glucose level= "+ str(mean_y))


print("Sum  of age= "+ str(sum_x))
print("Sum of glucose level= "+ str(sum_y))




# Using the formula to calculate a0 and a1
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
a1 = numer / denom
a0 = mean_y - (b1 * mean_x)

# Printing coefficients
print(" ")
print("linear regression coefficient(a1) ="+ str(a1) + "  and  "+ "constant(a0) ="+ str(a0))
print("LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)" + "   y = " + str(a0) + " + " +str(a1) + " *  X ")


# Plotting Values and Regression Line
max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = a0 + a1 * x

# Ploting Line
plt.plot(x, y, color='green', label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='red', label='Scatter Plot')


plt.xlabel('AGE')
plt.ylabel('GLUCOSE LEVEL')
plt.legend()
plt.show()

input_x=int(input("Enter the age to check glucose level: "))
y = a0 + a1 * input_x
print(y)
# Out:
#    age  glucose
# 0   43       99
# 1   21       65
# 2   25       79
# 3   42       75
# 4   57       87
# ----------------
# Mean age= 41.166666666666664
# Mean glucose level= 81.0
# Sum  of age= 247
# Sum of glucose level= 486
#
# linear regression coefficient(a1) =0.3852249832102082  and  constant(a0) =65.1415715245131
# LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)   y = 65.1415715245131 + 0.3852249832102082 *  X
# Enter the age to check glucose level: 0
# 65.1415715245131

# %% [markdown]
#  #### WEIGHT HEIGHT MODEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Reading Data
data = pd.read_csv('weight_height.csv')
# Printing the data  
print(data.head())
print("----------------")


# Collecting X and Y
X = data['weight'].values
Y = data['height'].values


# Calculating coefficient

# Mean and Sum of  X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

sum_x=np.sum(X)
sum_y=np.sum(Y)

print("Mean weight= "+ str(mean_x))
print("Mean height= "+ str(mean_y))


print("Sum  of weight= "+ str(sum_x))
print("Sum of height= "+ str(sum_y))




# Using the formula to calculate a0 and a1
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
a1 = numer / denom
a0 = mean_y - (b1 * mean_x)

# Printing coefficients
print(" ")
print("linear regression coefficient(a1) ="+ str(a1) + "  and  "+ "constant(a0) ="+ str(a0))
print("LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)" + "   y = " + str(a0) + " + " +str(a1) + " *  X ")


# Plotting Values and Regression Line
max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = a0 + a1 * x

# Ploting Line
plt.plot(x, y, color='green', label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='red', label='Scatter Plot')


plt.xlabel('WEIGHT')
plt.ylabel('HEIGHT')
plt.legend()
plt.show()

#input_x=int(input("Enter the age to check glucose level: "))
#y = a0 + a1 * input_x
#print(y)
# Out:
#    weight  height
# 0     140      60
# 1     155      62
# 2     159      67
# 3     179      70
# 4     192      71
# ----------------
# Mean weight= 176.71428571428572
# Mean height= 68.14285714285714
# Sum  of weight= 1237
# Sum of height= 477
#
# linear regression coefficient(a1) =0.20255876977374415  and  constant(a0) =0.06809939556748645
# LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)   y = 0.06809939556748645 + 0.20255876977374415 *  X

# %% [markdown]
# ### PRICE PREDICTION MODEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Reading Data
data = pd.read_csv('price.csv')
# Printing the data  
print(data.head())
print("----------------")


# Collecting X and Y
X = data['squarefeet'].values
Y = data['price'].values


# Calculating coefficient

# Mean and Sum of  X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

sum_x=np.sum(X)
sum_y=np.sum(Y)

print("Mean squarefeet= "+ str(mean_x))
print("Mean price= "+ str(mean_y))


print("Sum  of squarefeet= "+ str(sum_x))
print("Sum of price= "+ str(sum_y))




# Using the formula to calculate a0 and a1
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
a1 = numer / denom
a0 = mean_y - (b1 * mean_x)

# Printing coefficients
print(" ")
print("linear regression coefficient(a1) ="+ str(a1) + "  and  "+ "constant(a0) ="+ str(a0))
print("LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)" + "   y = " + str(a0) + " + " +str(a1) + " *  X ")


# Plotting Values and Regression Line
max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = a0 + a1 * x

# Ploting Line
plt.plot(x, y, color='green', label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='red', label='Scatter Plot')


plt.xlabel('SQUAREFEET')
plt.ylabel('PRICE')
plt.legend()
plt.show()

#input_x=int(input("Enter the age to check glucose level: "))
#y = a0 + a1 * input_x
#print(y)
# Out:
#    squarefeet  price
# 0         500      5
# 1         900     10
# 2        1200     13
# 3        1500     18
# 4        2000     25
# ----------------
# Mean squarefeet= 1614.2857142857142
# Mean price= 19.714285714285715
# Sum  of squarefeet= 11300
# Sum of price= 138
#
# linear regression coefficient(a1) =0.013670886075949368  and  constant(a0) =-602.1489014679075
# LINEAR REGRESSION EQUATION : (Y = A0 + A1*X)   y = -602.1489014679075 + 0.013670886075949368 *  X
